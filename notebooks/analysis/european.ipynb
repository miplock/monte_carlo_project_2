# %% [markdown]
# ### ile replikacji i dlaczego tyle

# %% [markdown]
# liczba replikacji eksperymentu $M=1000$

# %% [markdown]
# ### wartość blacka-scholesa dla tych parametrów

# %% [markdown]
# Krótka uwaga: to punkt odniesienia do błędu i coverage.

# %% [markdown]
# ### tabela główna

# %% [markdown]
# mean($\hat I$), sd($\hat I$), bias, MSE, coverage CI

# %% [markdown]
# ### empiryczny VRF

# %% [markdown]
# ### wykresy

# %% [markdown]
# ### analiza i interpretacja

# %% [markdown]
# ## Estimator statistics table
#
# Load stats from the .pkl file and display them as a table.

# %%
from pathlib import Path
import pickle
import sys

import pandas as pd

ROOT = Path.cwd().resolve()
while not (ROOT / "parameters.py").exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

stats_path = ROOT / "data" / "european_estimator_stats.pkl"
with stats_path.open("rb") as f:
    payload = pickle.load(f)

df = pd.DataFrame(payload["stats"]).T
df
# Out:
#                               mean       std      bias       mse  \
# crude                    16.262920  0.087710 -0.000278  0.007685
# stratified_proportional  16.259545  0.073901 -0.003653  0.005469
# stratified_optimal       16.263056  0.058010 -0.000142  0.003362
# antithetic               16.263128  0.067604 -0.000070  0.004566
# control                  16.263140  0.049019 -0.000058  0.002401
#
#                          ci_coverage_95
# crude                             0.945
# stratified_proportional           0.974
# stratified_optimal                0.946
# antithetic                        0.987
# control                           0.956
