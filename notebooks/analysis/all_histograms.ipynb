# %% [markdown]
# # All error histograms
#
# Displays all error histograms (European + barrier).

# %%
from pathlib import Path
import pickle
import sys

ROOT = Path.cwd().resolve()
while not (ROOT / "parameters.py").exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

PLOTS_DIR = ROOT / "plots"
PLOTS_DIR
# Out:
# PosixPath('/media/miplock/OS/Users/mikołaj/Desktop/laby_26/monte_carlo_project_2/plots')

# %% [markdown]
# ## European

# %%
hist_path = PLOTS_DIR / "european_errors_hist.pkl"
with hist_path.open("rb") as f:
    fig = pickle.load(f)
fig

# %% [markdown]
# ## Barrier C=105

# %%
hist_path = PLOTS_DIR / "barrier_errors_hist_C105.pkl"
with hist_path.open("rb") as f:
    fig = pickle.load(f)
fig

# %% [markdown]
# ## Barrier C=120

# %%
hist_path = PLOTS_DIR / "barrier_errors_hist_C120.pkl"
with hist_path.open("rb") as f:
    fig = pickle.load(f)
fig
