# %% [markdown]
# [Poprzedni rozdzial](rozdzial_06_dyskusja_wnioski.ipynb)

# %% [markdown]
# # 8. Uwagi

# %% [markdown]
# Kod źródłowy wykorzystany w projekcie był tworzony z użyciem narzędzi wspomagających programowanie opartych na sztucznej inteligencji, w szczególności ChatGPT (wersja 5.2), Codex oraz VS Code Copilot. Wygenerowane fragmenty kodu zostały następnie poddane ręcznemu przeglądowi i modyfikacjom, ze szczególnym uwzględnieniem poprawności merytorycznej, zgodności z założeniami modelu oraz poprawnej implementacji metod Monte Carlo i technik redukcji wariancji.

# %% [markdown]
# [Nastepny rozdzial](rozdzial_09_kod_zrodlowy.ipynb)
